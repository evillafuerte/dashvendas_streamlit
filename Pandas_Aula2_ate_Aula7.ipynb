# %%
# Importando biblioteca
import pandas as pd

# %%
# Lendo a base de dados
df = pd.read_csv("datasets\supermarket_sales1.csv", sep=";", parse_dates=["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               969 non-null    object
#  1   Branch                   969 non-null    object
#  2   City                     969 non-null    object
#  3   Customer type            969 non-null    object
#  4   Gender                   969 non-null    object
#  5   Product line             969 non-null    object
#  6   Unit price               969 non-null    float64
#  7   Quantity                 969 non-null    int64
#  8   Tax 5%                   969 non-null    float64
#  9   Total                    969 non-null    object
#  10  Date                     969 non-null    datetime64[ns]
#  11  Time                     969 non-null    object
#  12  Payment                  969 non-null    object
#  13  cogs                     969 non-null    float64
# ...

# %%
# Visualizando as 5 primeiras linhas
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
# 3       Health and beauty       58.22         8   23.288    489.048
# 4       Sports and travel       86.31         7  302.085  6.343.785
#
#          Date   Time      Payment    cogs gross margin percentage  \
# 0  01/05/2019  13:08      Ewallet  522.83           4.761.904.762
# 1  03/08/2019  10:29         Cash   76.40           4.761.904.762
# ...

# %% [markdown]
# ### Dicionário das variáveis
# * Invoice ID = Número de identificação da fatura do recibo de venda gerado por computador
# * Branch = Filial do supercentro (estão disponíveis 3 filiais identificadas por A, B e C).
# * City = Localização de supercentros
# * Customer type = Tipo de clientes, registrados por Associados para clientes com cartão de sócio e Normal e para cliente sem cartão de sócio.
# * Gender = Gênero do cliente
# * Product line = Grupos de categorização geral de itens - Acessórios eletrônicos, Acessórios de moda, Alimentos e bebidas, Saúde e beleza, Casa e estilo de vida, Esportes e viagens
# * Unit price = Preço de cada produto
# * Quantity = Número de produtos comprados pelo cliente
# * Tax 5% = Taxa de imposto de 5% para a compra do cliente
# * Total = Preço total incluindo impostos
# * Date = Data de compra (Registro disponível de janeiro de 2019 a março de 2019)
# * Time = Horário de compra (10h às 21h)
# * Payment = Pagamento usado pelo cliente para compra (3 métodos estão disponíveis – Dinheiro, Cartão de Crédito e Ewallet)
# * cogs = Custo dos bens vendidos
# * gross margin percentage = Porcentagem de margem bruta
# * gross income = Renda bruta
# * Rating = Classificação da estratificação do cliente em sua experiência geral de compra (numa escala de 1 a 10)

# %%
# Total de linhas e colunas
df.shape
# Out:
# (969, 17)

# %%
# Verificando o tipo de dado de cada coluna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               969 non-null    object
#  1   Branch                   969 non-null    object
#  2   City                     969 non-null    object
#  3   Customer type            969 non-null    object
#  4   Gender                   969 non-null    object
#  5   Product line             969 non-null    object
#  6   Unit price               969 non-null    float64
#  7   Quantity                 969 non-null    int64
#  8   Tax 5%                   969 non-null    float64
#  9   Total                    969 non-null    object
#  10  Date                     969 non-null    datetime64[ns]
#  11  Time                     969 non-null    object
#  12  Payment                  969 non-null    object
#  13  cogs                     969 non-null    float64
# ...

# %%
# Alterando o tipo de dado de uma coluna
#Trasnformando coluna de data em tipo Data
df["Date"] = pd.to_datetime(df["Date"])

# %%
#Retornando a data mais antiga
df["Date"].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
# Retornando a data mais recente
df["Date"].max()
# Out:
# Timestamp('2019-03-30 00:00:00')

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# 2 2019-03-03  13:23  Credit card  324.31           4.761.904.762
#
#    gross income  Rating
# 0       261.415     9.1
# 1         3.820     9.6
# 2       162.155     7.4

# %% [markdown]
# ### value_counts

# %%
# Total vendas por cidade
df["City"].value_counts()
# Out:
# Yangon       332
# Naypyidaw    319
# Mandalay     318
# Name: City, dtype: int64

# %%
# Total vendas por Gênero
df["Gender"].value_counts()
# Out:
# Female    487
# Male      482
# Name: Gender, dtype: int64

# %% [markdown]
# ### nlargest

# %%
df.nlargest(20, "Quantity")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 7    315-22-5665      C  Naypyidaw        Normal  Female
# 12   252-56-2699      A     Yangon        Normal    Male
# 13   829-34-3910      A     Yangon        Normal  Female
# 48   574-22-5561      C  Naypyidaw        Member  Female
# 57   817-48-8732      A     Yangon        Member  Female
# 61   199-75-8169      A     Yangon        Member    Male
# 63   877-22-3308      A     Yangon        Member    Male
# 66   232-11-3025      A     Yangon        Normal    Male
# 68   393-65-2792      C  Naypyidaw        Normal    Male
# 69   796-12-2025      C  Naypyidaw        Normal    Male
# 73   732-94-0499      C  Naypyidaw        Normal  Female
# 75   829-49-1914      C  Naypyidaw        Member  Female
# 88   225-32-0908      C  Naypyidaw        Normal  Female
# 92   766-85-7061      B   Mandalay        Normal    Male
# 104  861-77-0145      C  Naypyidaw        Member    Male
# ...

# %% [markdown]
# ### nsmallest

# %%
df.nsmallest(10, "Quantity")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 25   649-29-6775      B   Mandalay        Normal    Male
# 34   232-16-2483      C  Naypyidaw        Member  Female
# 39   280-35-5823      B   Mandalay        Member  Female
# 52   778-71-5554      C  Naypyidaw        Member    Male
# 67   382-03-4532      A     Yangon        Member  Female
# 85   504-35-8843      A     Yangon        Normal    Male
# 90   512-91-0811      C  Naypyidaw        Normal    Male
# 91   594-34-4444      A     Yangon        Normal    Male
# 96   163-56-7055      C  Naypyidaw        Member    Male
# 112  659-65-8956      B   Mandalay        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%    Total  \
# 25      Fashion accessories       33.52         1   1.6760   35.196
# 34        Sports and travel       68.12         1   3.4060   71.526
# 39       Home and lifestyle       86.72         1   4.3360   91.056
# ...

# %% [markdown]
# ### sort_values

# %%
df.sort_values(by="Quantity", ascending=False)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 73   732-94-0499      C  Naypyidaw        Normal  Female
# 430  235-46-8343      C  Naypyidaw        Member    Male
# 406  271-88-8734      C  Naypyidaw        Member  Female
# 379  308-47-4913      A     Yangon        Member  Female
# 104  861-77-0145      C  Naypyidaw        Member    Male
# ..           ...    ...        ...           ...     ...
# 418  837-55-7229      B   Mandalay        Normal  Female
# 855  325-89-4209      A     Yangon        Member    Male
# 67   382-03-4532      A     Yangon        Member  Female
# 709  238-45-6950      B   Mandalay        Member    Male
# 462  575-67-1508      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 73   Electronic accessories       41.65        10  20.8250    437.325
# 430      Food and beverages       27.66        10  13.8300     290.43
# ...

# %% [markdown]
# ### Filtros

# %%
# Filtrando pelo gênero Female
df_female = df[df["Gender"] == "Female"]
df_female.shape
# Out:
# (487, 17)

# %%
df_female.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 6  355-53-5943      A     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 6  Electronic accessories       68.84         6   20.652    433.692
#
#         Date   Time  Payment    cogs gross margin percentage  gross income  \
# 0 2019-01-05  13:08  Ewallet  522.83           4.761.904.762       261.415
# 1 2019-03-08  10:29     Cash   76.40           4.761.904.762         3.820
# 6 2019-02-25  14:36  Ewallet  413.04           4.761.904.762        20.652
#
#    Rating
# 0     9.1
# 1     9.6
# 6     5.8

# %%
df_female.groupby("Product line")["Quantity"].sum().sort_values(ascending=False)
# Out:
# Product line
# Food and beverages        504
# Fashion accessories       501
# Sports and travel         487
# Home and lifestyle        484
# Electronic accessories    479
# Health and beauty         336
# Name: Quantity, dtype: int64

# %%
df_male = df.loc[df["Gender"] == "Male"]
df_male.shape
# Out:
# (482, 17)

# %%
df_male.groupby("Product line")["Quantity"].sum().sort_values(ascending=False)
# Out:
# Product line
# Health and beauty         491
# Electronic accessories    459
# Food and beverages        427
# Sports and travel         407
# Home and lifestyle        389
# Fashion accessories       363
# Name: Quantity, dtype: int64

# %%
df.loc[(df["Gender"] != "Female") & (df["City"] == "Yangon")]
# Out:
#       Invoice ID Branch    City Customer type Gender            Product line  \
# 2    631-41-3108      A  Yangon        Normal   Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member   Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal   Male       Sports and travel
# 12   252-56-2699      A  Yangon        Normal   Male      Food and beverages
# 16   765-26-6951      A  Yangon        Normal   Male       Sports and travel
# ..           ...    ...     ...           ...    ...                     ...
# 942  531-56-4728      A  Yangon        Normal   Male      Home and lifestyle
# 950  809-46-1866      A  Yangon        Normal   Male       Health and beauty
# 961  745-74-0715      A  Yangon        Normal   Male  Electronic accessories
# 966  727-02-1313      A  Yangon        Member   Male      Food and beverages
# 967  347-56-2442      A  Yangon        Normal   Male      Home and lifestyle
#
# ...

# %%
df.loc[(df["Gender"] != "Female") | (df["City"] == "Yangon")]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyidaw        Normal    Male
# ..           ...    ...        ...           ...     ...
# 962  690-01-6631      B   Mandalay        Normal    Male
# 964  233-67-5758      C  Naypyidaw        Normal    Male
# 966  727-02-1313      A     Yangon        Member    Male
# 967  347-56-2442      A     Yangon        Normal    Male
# 968  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  261.415  5.489.715
# 2        Home and lifestyle       46.33         7  162.155  3.405.255
# ...

# %%
# isin
lista = ["A", "B"]
df[~df["Branch"].isin(lista)]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyidaw        Normal  Female
# 5    699-14-3026      C  Naypyidaw        Normal    Male
# 7    315-22-5665      C  Naypyidaw        Normal  Female
# 19   300-71-4605      C  Naypyidaw        Member    Male
# 33   183-56-6882      C  Naypyidaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 952  148-41-7930      C  Naypyidaw        Normal    Male
# 953  189-40-5216      C  Naypyidaw        Normal    Male
# 957  267-62-7380      C  Naypyidaw        Member    Male
# 963  652-49-6720      C  Naypyidaw        Member  Female
# 964  233-67-5758      C  Naypyidaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 1    Electronic accessories       15.28         5    3.820      80.22
# 5    Electronic accessories       85.39         7  298.865  6.276.165
# ...

# %% [markdown]
# ### Adicionando uma nova Coluna

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# 2 2019-03-03  13:23  Credit card  324.31           4.761.904.762
#
#    gross income  Rating
# 0       261.415     9.1
# 1         3.820     9.6
# 2       162.155     7.4

# %%
df["Venda sem taxa"] = df["Unit price"] * df["Quantity"]

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# 2 2019-03-03  13:23  Credit card  324.31           4.761.904.762
#
#    gross income  Rating  Venda sem taxa
# 0       261.415     9.1          522.83
# 1         3.820     9.6           76.40
# 2       162.155     7.4          324.31

# %%
# Informando onde vai inserir a coluna
df.insert(8, "Venda s/ Taxa", df["Unit price"] * df["Quantity"])

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity  Venda s/ Taxa   Tax 5%  \
# 0       Health and beauty       74.69         7         522.83  261.415
# 1  Electronic accessories       15.28         5          76.40    3.820
# 2      Home and lifestyle       46.33         7         324.31  162.155
#
#        Total       Date   Time      Payment    cogs gross margin percentage  \
# 0  5.489.715 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1      80.22 2019-03-08  10:29         Cash   76.40           4.761.904.762
# 2  3.405.255 2019-03-03  13:23  Credit card  324.31           4.761.904.762
#
#    gross income  Rating  Venda sem taxa
# 0       261.415     9.1          522.83
# 1         3.820     9.6           76.40
# ...

# %% [markdown]
# ### Renoemando Colunas

# %%
df.rename(columns={"Venda s/ Taxa":"Receita"}, inplace=True)

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity  Receita   Tax 5%      Total  \
# 0       Health and beauty       74.69         7   522.83  261.415  5.489.715
# 1  Electronic accessories       15.28         5    76.40    3.820      80.22
# 2      Home and lifestyle       46.33         7   324.31  162.155  3.405.255
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# 2 2019-03-03  13:23  Credit card  324.31           4.761.904.762
#
#    gross income  Rating  Venda sem taxa
# 0       261.415     9.1          522.83
# 1         3.820     9.6           76.40
# 2       162.155     7.4          324.31

# %% [markdown]
# ### Removendo Colunas

# %%
df.drop(columns=["Receita", "Venda sem taxa"], inplace=True)

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
# 3       Health and beauty       58.22         8   23.288    489.048
# 4       Sports and travel       86.31         7  302.085  6.343.785
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# ...

# %% [markdown]
# ### Dataset: https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                              object
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage            object
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df["Total"] = df["Total"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df["Total"] = df["Total"].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
#df["Total"] = pd.to_numeric(df["Total"], errors="coerce")

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyidaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyidaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
# 3       Health and beauty       58.22         8   23.288    489.048
# ...

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                              object
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage            object
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
len("3405255")
# Out:
# 9

# %%
"Fernanda" + "Santos"
# Out:
# 'FernandaSantos'

# %%
a
# Out:
# '3405255'

# %%
a = a.replace(".", "")

# %%
def corrige_numero(coluna):
    if len(coluna) > 8:
        coluna = coluna.replace(".", "")
        coluna = coluna[0:3] + "." + coluna[3:]
        return coluna
    else:
        return coluna

# %%
df["Total"] = df["Total"].apply(corrige_numero)

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  261.415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5    3.820     80.22 2019-03-08
# 2      Home and lifestyle       46.33         7  162.155  340.5255 2019-03-03
#
#     Time      Payment    cogs gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83           4.761.904.762       261.415     9.1
# 1  10:29         Cash   76.40           4.761.904.762         3.820     9.6
# 2  13:23  Credit card  324.31           4.761.904.762       162.155     7.4

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage            object
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df["Total"] = df["Total"].astype(float)

# %%
df.groupby("Branch")["Total"].sum().sort_values(ascending=False)
# Out:
# Branch
# C    119896.8960
# A    114398.2875
# B    111442.0545
# Name: Total, dtype: float64
